# %%
#This is for HW3_2

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt
from scipy import optimize as opt
import scipy.io
import random

# %%
weights = scipy.io.loadmat(r"C:\Users\Yow-Gwo Wang\Desktop\ML\machine-learning-ex3\machine-learning-ex3\ex3\ex3weights.mat")
input_data = scipy.io.loadmat(r"C:\Users\Yow-Gwo Wang\Desktop\ML\machine-learning-ex3\machine-learning-ex3\ex3\ex3data1.mat")

# %%
def displayData(X):
    X = X.reshape(20, 20).transpose()
    plt.imshow(X)
    plt.show()

# %%
def sigmoid(x):
    #z = np.dot(theta.transpose(), X)
    g = 1/(1 + np.exp(-x))
    return g

# %%
def predict(Theta1, Theta2, X):
    #Load the entire X matrix in, then do the calulation 1 by 1.
    #Useful values
    m = X.shape[0]
    p = np.zeros(m)
    X = np.column_stack([np.ones((m, 1)), X])
    for idx in range(m):
        image = np.matrix(X[idx])
        #X is 1x400 -> 1x401
        #1st layer using Theta1:
        #Theta1: 25*401
        #X_prime: 1x401 -> transpose: 401x1   
        z2 = np.dot(Theta1, image.transpose())
        a2 = sigmoid(z2)
        #2nd layer using Theta2
        #a2 is 25 x1 -> 26 x1
        #Theta_2 is 10x26    
        to_add = np.ones((1,1))
        a2_prime = np.vstack([np.ones((1,1)), a2])
        z3 = np.dot(Theta2, a2_prime)
        a3 = sigmoid(z3)
        p[idx] = np.argmax(a3, axis=0)+1
    return p

# %%
theta1 = weights['Theta1']
theta2 = weights['Theta2']
print(theta1.shape)
print(theta2.shape)
input_X = input_data['X']
input_y = input_data['y']
print(input_X.shape[0])
# Out:
# (25, 401)
# (10, 26)
# 5000

# %%
p = predict(theta1, theta2, input_X)
# Out:
# (5000, 401)

# %%
correct = [1 if a == b else 0 for (a, b) in zip(p, input_y)]
accuracy = sum(correct)/ float(len(correct))
print('accuracy = {0}%'.format(accuracy * 100))
# Out:
# accuracy = 97.52%

# %%
#Randomly permute examples
rp = np.random.permutation(input_X.shape[0])
for i in range(100):
    #Display 
    displayData(input_X[rp[i], :])
    pred = predict(theta1, theta2, np.matrix(input_X[rp[i],:]))
    if pred == 10:
        pred = 0
    if int(input_y[rp[i]]) == 10:
        y = 0
    else:
        y = int(input_y[rp[i]])
    print('Neural Network Prediction: %d' % int(pred))
    print('y output is: %d' % int(y))
# Out:
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 5
# y output is: 5
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 3
# y output is: 3
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 4
# y output is: 4
# Neural Network Prediction: 5
# y output is: 5
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 3
# y output is: 3
# Neural Network Prediction: 7
# y output is: 7
# Neural Network Prediction: 7
# y output is: 7
# Neural Network Prediction: 4
# y output is: 4
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 5
# y output is: 5
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 4
# y output is: 4
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 0
# y output is: 0
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 0
# y output is: 0
# Neural Network Prediction: 5
# y output is: 5
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 4
# y output is: 4
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 6
# y output is: 6
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 6
# y output is: 6
# Neural Network Prediction: 3
# y output is: 3
# Neural Network Prediction: 5
# y output is: 5
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 5
# y output is: 5
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 2
# y output is: 2
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 6
# y output is: 6
# Neural Network Prediction: 3
# y output is: 3
# Neural Network Prediction: 3
# y output is: 9
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 3
# y output is: 3
# Neural Network Prediction: 6
# y output is: 6
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 6
# y output is: 6
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 7
# y output is: 7
# Neural Network Prediction: 7
# y output is: 7
# Neural Network Prediction: 0
# y output is: 0
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 0
# y output is: 0
# Neural Network Prediction: 4
# y output is: 4
# Neural Network Prediction: 6
# y output is: 6
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 3
# y output is: 3
# Neural Network Prediction: 2
# y output is: 2
# Neural Network Prediction: 2
# y output is: 2
# Neural Network Prediction: 6
# y output is: 6
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 6
# y output is: 6
# Neural Network Prediction: 5
# y output is: 5
# Neural Network Prediction: 3
# y output is: 3
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 2
# y output is: 2
# Neural Network Prediction: 0
# y output is: 0
# Neural Network Prediction: 2
# y output is: 2
# Neural Network Prediction: 3
# y output is: 3
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 0
# y output is: 0
# Neural Network Prediction: 2
# y output is: 2
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 2
# y output is: 2
# Neural Network Prediction: 7
# y output is: 7
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 4
# y output is: 4
# Neural Network Prediction: 5
# y output is: 5
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 4
# y output is: 4
# Neural Network Prediction: 5
# y output is: 5
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 2
# y output is: 2
# Neural Network Prediction: 2
# y output is: 2
# Neural Network Prediction: 8
# y output is: 8
# Neural Network Prediction: 3
# y output is: 3
# Neural Network Prediction: 6
# y output is: 6
# Neural Network Prediction: 4
# y output is: 4
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 2
# y output is: 2
# Neural Network Prediction: 1
# y output is: 1
# Neural Network Prediction: 9
# y output is: 9
# Neural Network Prediction: 6
# y output is: 6
# Neural Network Prediction: 7
# y output is: 7
